# %%
import os
import anthropic
import json

# Khởi tạo Anthropic client
claude_client = anthropic.Anthropic(
    api_key=os.getenv('ANTHROPIC_API_KEY')
)

def generate_questions_answers(chunk):
    """Gửi chunk tới Claude để tạo câu hỏi và câu trả lời."""
    try:
        response = claude_client.messages.create(
            max_tokens=8192,
            system="Bạn là người am hiểu lịch sử Việt Nam, luôn trả lời với đầy đủ và chi tiết, nhiều thông tin và khía cạnh nhất có thể.",
            messages=[
                {"role": "user", "content": f"""
                Hãy trả về kết quả dưới dạng JSON như sau:
                {{
                    "questions": [
                        "Câu hỏi 1",
                        "Câu hỏi 2"
                    ],
                    ,
                    "answers": [
                        "Câu trả lời 1",
                        "Câu trả lời 2"
                    ]
                }}
                Tạo 20 cặp câu hỏi và trả lời dựa vào nội dung sau: {chunk}
                Câu trả lời phải dài và đầy đủ nhất có thể, kết hợp cả bối cảnh, nguyên nhân, sự kiện và diễn giải. 
                Sử dụng hết mức các thông tin trong nội dung gốc, chỉ lược bỏ những phần thật sự không cần thiết.
                Câu trả lời có thể lặp lại thông tin trong các câu trả lời khác.
                """},
            ],
            model="claude-3-5-haiku-latest",
        )

        # Lấy nội dung từ phản hồi
        content = response.content[0].text
        # Chuyển đổi chuỗi JSON thành đối tượng Python
        questions_answers = json.loads(content)
        return json.dumps(questions_answers, ensure_ascii=False, indent=2)

    except Exception as e:
        print(f"Có lỗi xảy ra: {e}")
        return None

# Ví dụ sử dụng
if __name__ == "__main__":
    # Đọc nội dung từ tệp
    try:
        with open("../test-output/input_context.txt", "r", encoding="utf-8") as file:
            chunk = file.read().strip()
    except FileNotFoundError:
        print("Tệp không tìm thấy. Vui lòng kiểm tra đường dẫn tệp.")
        chunk = ""

    if chunk:
        result = generate_questions_answers(chunk)
        
        if result:
            print(result)
            # Lưu kết quả vào tệp
            try:
                with open("../test-output/result.txt", "w", encoding="utf-8") as result_file:
                    result_file.write(result)
                print("Kết quả đã được lưu vào tệp result.txt.")
            except Exception as e:
                print(f"Đã xảy ra lỗi khi lưu kết quả: {e}")
        else:
            print("Không có kết quả để lưu.")
    else:
        print("Không có nội dung để xử lý.")
# Out:
# {
#   "questions": [
#     "Ai là Tướng Lê Trọng Tấn?",
#     "Tướng Lê Trọng Tấn có vai trò gì trong chiến tranh chống Pháp và chống Mỹ?",
#     "Đại Đoàn 320 của Lê Trọng Tấn đã làm gì tại Điện Biên Phủ?",
#     "Vai trò của Lê Trọng Tấn trong chiến dịch Hồ Chí Minh năm 1975?",
#     "Tại sao Tướng Giáp lại đánh giá cao Lê Trọng Tấn?",
#     "Lê Trọng Tấn có vị trí như thế nào trong Quân đội nhân dân Việt Nam?",
#     "Chi tiết về sự kiện Lê Trọng Tấn cắm cờ tại hầm De Castries?",
#     "Vai trò của Lê Trọng Tấn tại Đại hội Đảng lần thứ VI?",
#     "Chiếc xe tăng 390 của Lê Trọng Tấn có ý nghĩa như thế nào?",
#     "Tướng Lê Trọng Tấn được đánh giá như thế nào trong giới quân sự?",
#     "Mối quan hệ của Lê Trọng Tấn với Tướng Võ Nguyên Giáp?",
#     "Lê Trọng Tấn đã đóng góp gì cho sự nghiệp cách mạng của Việt Nam?",
#     "Sự kiện Lê Trọng Tấn cắm cờ tại Điện Biên Phủ diễn ra như thế nào?",
#     "Vai trò của Lê Trọng Tấn trong việc thống nhất đất nước?",
#     "Tại sao Lê Trọng Tấn lại được bầu là trưởng đoàn đại biểu quân đội?",
#     "Đóng góp của Lê Trọng Tấn tại Đại hội Đảng toàn quân?",
#     "Chi tiết về hoạt động của Lê Trọng Tấn trong hai cuộc kháng chiến?",
#     "Vị trí quân sự của Lê Trọng Tấn trong quân đội?",
#     "Ý nghĩa chiến lược của Đại Đoàn 320 do Lê Trọng Tấn lãnh đạo?",
#     "Đánh giá của giới quân sự về năng lực của Tướng Lê Trọng Tấn?"
#   ],
#   "answers": [
#     "Lê Trọng Tấn là một trong những vị tướng danh tiếng của Quân đội Nhân dân Việt Nam, được Tướng Võ Nguyên Giáp đánh giá là 'một trong các vị tướng giỏi nhất Việt Nam qua các thời đại'. Ông là một trong những chỉ huy quân sự xuất sắc, đã sát cánh với Tướng Giáp suốt hai cuộc kháng chiến chống Pháp và chống Mỹ.",
#     "Trong cuộc kháng chiến chống Pháp, Lê Trọng Tấn là một trong những chỉ huy chủ chốt của Đại Đoàn 320, đóng vai trò quan trọng tại trận Điện Biên Phủ. Ông đã lãnh đạo đơn vị cắm cờ tại hầm De Castries, góp phần quyết định vào chiến thắng lịch sử. Trong cuộc kháng chiến chống Mỹ, ông tiếp tục là một trong những vị tướng chủ chốt, đặc biệt là trong Chiến dịch Hồ Chí Minh năm 1975.",
#     "Tại Điện Biên Phủ, Đại Đoàn 320 do Lê Trọng Tấn chỉ huy đã là lực lượng quyết định trong việc tiến công và chiếm lĩnh hầm chỉ huy của Đại tá De Castries. Chính Đại Đoàn này đã cắm cờ tại hầm De Castries, trở thành biểu tượng của chiến thắng huy hoàng, kết thúc thắng lợi trận Điện Biên Phủ.",
#     "Trong Chiến dịch Hồ Chí Minh năm 1975, Lê Trọng Tấn đóng vai trò then chốt với Cánh Quân Phía Đông. Chính chiếc xe tăng 390 của ông đã húc đổ cổng Dinh Độc Lập, kết thúc cuộc chiến tranh thống nhất hai miền Nam Bắc. Đây được coi là một trong những hành động quyết định trong việc giải phóng hoàn toàn miền Nam.",
#     "Tướng Giáp đánh giá cao Lê Trọng Tấn vì những năng lực quân sự xuất sắc, sự can trường và tài chỉ huy chiến đấu. Ông được xem là một trong những vị tướng giỏi nhất, có đóng góp quan trọng trong hai cuộc kháng chiến chống Pháp và chống Mỹ.",
#     "Trong Quân đội Nhân dân Việt Nam, Lê Trọng Tấn là một trong những vị tướng hàng đầu. Ông được bầu làm trưởng đoàn đại biểu quân đội tại Đại hội Đảng toàn quân năm 1986, cho thấy uy tín và vị thế quan trọng của ông trong hệ thống quân đội.",
#     "Tại hầm De Castries, Đại Đoàn 320 do Lê Trọng Tấn chỉ huy đã tiến hành một đợt tấn công quyết liệt. Khi chiếm được hầm chỉ huy, binh lính đã cắm lá cờ Quyết Chiến Quyết Thắng, trở thành một trong những khoảnh khắc biểu tượng của chiến thắng Điện Biên Phủ.",
#     "Tại Đại hội Đảng lần thứ VI vào ngày 18-10-1986, Lê Trọng Tấn được bầu làm trưởng đoàn đại biểu quân đội. Điều này cho thấy uy tín và vai trò quan trọng của ông trong hệ thống lãnh đạo Đảng và Quân đội.",
#     "Chiếc xe tăng 390 của Lê Trọng Tấn trở thành biểu tượng của Chiến dịch Hồ Chí Minh. Khi húc đổ cổng Dinh Độc Lập, nó không chỉ là một hành động quân sự thuần túy mà còn mang ý nghĩa chính trị sâu sắc - kết thúc cuộc chiến tranh thống nhất hai miền Nam Bắc.",
#     "Trong giới quân sự, Lê Trọng Tấn được đánh giá là một trong những vị tướng xuất sắc nhất của Việt Nam. Ông được biết đến với tài năng chỉ huy, chiến lược quân sự và tinh thần chiến đấu kiên cường.",
#     "Mối quan hệ giữa Lê Trọng Tấn và Tướng Võ Nguyên Giáp rất gắn bó. Giáp coi Lê Trọng Tấn như một trong những vị tướng giỏi nhất, hai người đã cùng nhau lãnh đạo quân đội qua hai cuộc kháng chiến khốc liệt.",
#     "Lê Trọng Tấn đóng góp to lớn cho sự nghiệp cách mạng thông qua vai trò quân sự xuất sắc. Ông đã góp phần quan trọng trong các chiến dịch then chốt như Điện Biên Phủ và Chiến dịch Hồ Chí Minh, giúp đất nước giành độc lập và thống nhất.",
#     "Sự kiện Lê Trọng Tấn cắm cờ tại Điện Biên Phủ diễn ra trong những giờ phút cuối cùng của trận chiến. Sau khi chiếm được hầm chỉ huy của De Castries, Đại Đoàn 320 đã cắm lá cờ Quyết Chiến Quyết Thắng, báo hiệu chiến thắng hoàn toàn.",
#     "Vai trò của Lê Trọng Tấn trong việc thống nhất đất nước rất quan trọng. Ông là một trong những chỉ huy chủ chốt trong Chiến dịch Hồ Chí Minh, với chiếc xe tăng 390 húc đổ cổng Dinh Độc Lập, kết thúc cuộc chiến tranh phân chia.",
#     "Lê Trọng Tấn được bầu là trưởng đoàn đại biểu quân đội do uy tín, năng lực và những đóng góp xuất sắc của ông cho sự nghiệp cách mạng. Ông được coi là một trong những vị tướng tiêu biểu của quân đội.",
#     "Tại Đại hội Đảng toàn quân, Lê Trọng Tấn thể hiện vai trò lãnh đạo quan trọng. Việc ông được bầu làm trưởng đoàn đại biểu cho thấy vị thế và ảnh hưởng của ông trong hệ thống quân đội.",
#     "Trong hai cuộc kháng chiến, Lê Trọng Tấn luôn là một trong những chỉ huy chủ chốt. Ông tham gia các chiến dịch then chốt như Điện Biên Phủ và Hồ Chí Minh, góp phần quan trọng vào những chiến thắng của quân đội nhân dân.",
#     "Về mặt quân sự, Lê Trọng Tấn là một vị tướng cấp cao, chỉ huy Đại Đoàn 320, một trong những đơn vị tinh nhuệ nhất của quân đội. Ông được biết đến với tài năng chỉ huy và chiến lược quân sự xuất sắc.",
#     "Đại Đoàn 320 do Lê Trọng Tấn lãnh đạo có ý nghĩa chiến lược rất quan trọng. Đơn vị này đã góp phần quyết định trong các trận đánh then chốt như Điện Biên Phủ và Chiến dịch Hồ Chí Minh.",
#     "Giới quân sự đánh giá Tướng Lê Trọng Tấn là một vị tướng tài năng, can trường và có tầm ảnh hưởng lớn. Ông được coi là một trong những vị tướng xuất sắc nhất của Việt Nam trong thế kỷ 20."
#   ]
# }
# Kết quả đã được lưu vào tệp result.txt.
